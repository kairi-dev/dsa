# %% [markdown]
# # 動的計画法 - 穴埋め演習（説明力重視）
#
# 対応教材: `learn/12_dynamic_programming.ipynb`

# %% [markdown]
# ## 問題
# `___` を埋めたあと、**なぜその記述になるか**を1〜2文で説明してください。

# %%
def fib(n):
    dp=[0]*(n+1)
    if n>=1: dp[1]=1
    for i in range(2,n+1):
        dp[i]=dp[i-1]+dp[i-2]
    return dp[___]

# %%
# 答え
# n

# 正解理由
# この補完がないと、その章の中核操作が成立しない。

# 誤答時の典型誤解
# 計算量かデータ構造の前提を取り違えている可能性が高い。

# %% [markdown]
# ## 実務ミニ課題
# この穴埋め部分を、実務のどの処理に置き換えられるかを「入力・処理・出力」で説明してください。
