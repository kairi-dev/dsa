# %% [markdown]
# # 計算量解析 - 選択問題（説明力重視）
#
# 対応教材: `learn/01_complexity.ipynb`

# %% [markdown]
# ## 問題1
# O(log n)がO(n)より有利になりやすい理由は？
#
# - A. 選択肢A
# - B. 選択肢B
# - C. 選択肢C
# - D. 選択肢D

# %%
answer_1='___'  # A/B/C/D
reason_1='ここに理由を書く'
print(answer_1, reason_1)

# %% [markdown]
# ## 問題2
# set検索を選ぶ条件として適切なのは？
#
# - A. 選択肢A
# - B. 選択肢B
# - C. 選択肢C
# - D. 選択肢D

# %%
answer_2='___'  # A/B/C/D
reason_2='ここに理由を書く'
print(answer_2, reason_2)

# %%
# 答え
correct_1='B'
correct_2='B'
print(correct_1, correct_2)

# 正解理由
# 用語定義・使いどころ・計算量の3点で説明できればOK。

# 誤答時の典型誤解
# 手法の前提条件を満たしていないのに適用してしまう。

# %% [markdown]
# ## 実務ミニ課題
# この章の手法を、自分の業務データに当てはめるならどの処理に使うか、理由付きで1段落で書く。
