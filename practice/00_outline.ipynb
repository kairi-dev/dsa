# %% [markdown]
# # Practiceガイド（説明力重視）
#
# この演習は「当てる」より「説明できる」を重視します。

# %% [markdown]
# ## 進め方
# 1. `learn/xx` の用語辞典と概念説明を読了
# 2. `xx_mc` で概念選択 + 理由記述
# 3. `xx_fill` で穴埋め + 補完理由記述
# 4. 実務ミニ課題で適用場面を1つ書く

# %%
record = {'topic':'01_complexity', 'mc_reason_written': False, 'fill_reason_written': False, 'business_case': ''}
record
