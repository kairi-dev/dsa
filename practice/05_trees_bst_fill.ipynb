# %% [markdown]
# # 木構造・二分探索木 - 穴埋め演習（説明力重視）
#
# 対応教材: `learn/05_trees_bst.ipynb`

# %% [markdown]
# ## 問題
# `___` を埋めたあと、**なぜその記述になるか**を1〜2文で説明してください。

# %%
def inorder(node):
    if node is None:
        return []
    return inorder(node.l)+[node.v]+inorder(node.___)

# %%
# 答え
# r

# 正解理由
# この補完がないと、その章の中核操作が成立しない。

# 誤答時の典型誤解
# 計算量かデータ構造の前提を取り違えている可能性が高い。

# %% [markdown]
# ## 実務ミニ課題
# この穴埋め部分を、実務のどの処理に置き換えられるかを「入力・処理・出力」で説明してください。
