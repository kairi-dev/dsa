# %% [markdown]
# # Phase 1: 線形構造と基本パターン
#
# 戻る: [00_overview.ipynb](./00_overview.ipynb)
#
# ## この Phase のテーマ
#
# - **DS**: 動的配列のイメージ、連結リスト、スタック、キュー、（必要なら）ハッシュテーブルの衝突の概念
# - **アルゴリズム**: ソート（安定性・用途）、二分探索（境界）、スライディングウィンドウ / 二ポインタの型
# - **レビュー観点**: ループ不変条件、オフバイワン、空配列
#
# ## 完了条件（出口基準）
#
# 1. 核となる DS/アルゴリズムを 1 つ以上、図や例で説明できる。
# 2. 主要操作の計算量を短文で言える（可能ならトレードオフ 1 組）。
# 3. 根拠をトレース・対比例・API 期待値などのいずれかで残す（実装は任意）。
# 4. ノート末尾の **感想** を書く。
#
# ---
#
# ## 学習メモ（ここから自由にセルを追加）
#
# （Markdown / コードセルを追加してよい）

# %% [markdown]
# ## 感想（この Phase の振り返り）
#
# - 腹落ちしたこと:
# - まだ曖昧:
# - 次に試したいこと:
