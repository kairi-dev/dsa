# %% [markdown]
# # Phase 4: 貪欲と動的計画法（基礎）
#
# 戻る: [00_overview.ipynb](./00_overview.ipynb)
#
# ## この Phase のテーマ
#
# - 貪欲の **反例** の見つけ方
# - 線形 DP・ナップサック入門、メモ化再帰とボトムアップの対応
# - 部分問題の定義・漸化式・初期条件を一文で書けるか
#
# ## 完了条件（出口基準）
#
# 1. 核となる DS/アルゴリズムを 1 つ以上、図や例で説明できる。
# 2. 主要操作の計算量を短文で言える（可能ならトレードオフ 1 組）。
# 3. 根拠をトレース・対比例・API 期待値などのいずれかで残す（実装は任意）。
# 4. ノート末尾の **感想** を書く。
#
# ---
#
# ## 学習メモ（ここから自由にセルを追加）

# %% [markdown]
# ## 感想（この Phase の振り返り）
#
# - 腹落ちしたこと:
# - まだ曖昧:
# - 次に試したいこと:
