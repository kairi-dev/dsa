# %% [markdown]
# # Phase 2: 木・ヒープ・優先度付き処理
#
# 戻る: [00_overview.ipynb](./00_overview.ipynb)
#
# ## この Phase のテーマ
#
# - **DS**: 二分木、BST、ヒープ（優先度キュー）
# - **アルゴリズム**: DFS/BFS のテンプレ、木の高さ・走査の応用
# - **現実例**: タスクの優先度、トップ K、階層データの走査
#
# ## 完了条件（出口基準）
#
# 1. 核となる DS/アルゴリズムを 1 つ以上、図や例で説明できる。
# 2. 主要操作の計算量を短文で言える（可能ならトレードオフ 1 組）。
# 3. 根拠をトレース・対比例・API 期待値などのいずれかで残す（実装は任意）。
# 4. ノート末尾の **感想** を書く。
#
# ---
#
# ## 学習メモ（ここから自由にセルを追加）

# %% [markdown]
# ## 感想（この Phase の振り返り）
#
# - 腹落ちしたこと:
# - まだ曖昧:
# - 次に試したいこと:
