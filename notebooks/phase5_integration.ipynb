# %% [markdown]
# # Phase 5: 統合（現実問題に近い小課題）
#
# 戻る: [00_overview.ipynb](./00_overview.ipynb)
#
# ## この Phase のテーマ
#
# - これまでの内容を組み合わせた **中規模の 1 課題**（設計メモ付き）
# - 「なぜその DS か」「代替案と計算量」を短く書く
# - **AI 連携**: 仕様（制約・テストケース・期待する計算量）を先に書き、生成物をチェックリストで査読
#
# ## 完了条件（出口基準）
#
# 1. 核となる DS/アルゴリズムを 1 つ以上、図や例で説明できる。
# 2. 主要操作の計算量を短文で言える（可能ならトレードオフ 1 組）。
# 3. 根拠をトレース・対比例・API 期待値などのいずれかで残す（実装は任意）。
# 4. ノート末尾の **感想** を書く。
#
# ---
#
# ## 学習メモ（ここから自由にセルを追加）

# %% [markdown]
# ## 感想（この Phase の振り返り）
#
# - 腹落ちしたこと:
# - まだ曖昧:
# - 次に試したいこと:
