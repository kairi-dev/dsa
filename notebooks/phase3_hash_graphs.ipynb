# %% [markdown]
# # Phase 3: ハッシュとグラフ
#
# 戻る: [00_overview.ipynb](./00_overview.ipynb)
#
# ## この Phase のテーマ
#
# - **DS**: ハッシュマップの典型利用、隣接リストグラフ
# - **アルゴリズム**: BFS/DFS、トポロジカルソート、Union-Find（概念〜実装）、最短経路の入口（重みなし BFS、ダイクストラは必要に応じて）
# - **レビュー観点**: 訪問管理、重複辺、非連結グラフ
#
# ## 完了条件（出口基準）
#
# 1. 核となる DS/アルゴリズムを 1 つ以上、図や例で説明できる。
# 2. 主要操作の計算量を短文で言える（可能ならトレードオフ 1 組）。
# 3. 根拠をトレース・対比例・API 期待値などのいずれかで残す（実装は任意）。
# 4. ノート末尾の **感想** を書く。
#
# ---
#
# ## 学習メモ（ここから自由にセルを追加）

# %% [markdown]
# ## 感想（この Phase の振り返り）
#
# - 腹落ちしたこと:
# - まだ曖昧:
# - 次に試したいこと:
